# %%
import matplotlib.pyplot as plt

points1 = {
    10: 0.3461000919342041,
    20: 0.3626999855041504,
    50: 0.3661000728607178,
    100: 0.5730001926422119,
    500: 0.4872000217437744,
    1000: 1.3842999935150146,
    3000: 1.181800127029419,
    6000: 3.474100112915039,
    10000: 3.26170015335083
}

points2 = {
    10: 1.8460001945495605,
    20: 2.3369998931884766,
    50: 3.132999897003174,
    100: 3.9646999835968018,
    500: 7.891000032424927,
    1000: 13.206400156021118,
    3000: 49.752699851989746,
    6000: 57.75859999656677,
    10000: 84.37769985198975
}

x1 = list(points1.keys())
y1 = list(points1.values())
x2 = list(points2.keys())
y2 = list(points2.values())

plt.plot(x1, y1, marker='o', markersize = 3, linestyle='-', color='r', label='Jarvis March')
plt.plot(x2, y2, marker='o', markersize = 3, linestyle='-', color='b', label='KPS')

plt.xlabel('Number of Points')
plt.ylabel('Time Elapsed (ms)')
plt.title('Convex Hull Computation')

plt.legend()
plt.xlim(0)
plt.ylim(0)
plt.grid(True)

plt.show()
